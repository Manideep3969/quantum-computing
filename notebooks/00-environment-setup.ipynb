# %% [markdown]
# # 00 — Environment Setup
#
# Verify that all dependencies are correctly installed and IBM Quantum connectivity works.

# %%
import sys
print(f"Python: {sys.version}")

import qiskit
print(f"Qiskit: {qiskit.__version__}")

import qiskit_aer
print(f"Qiskit Aer: {qiskit_aer.__version__}")

import qiskit_ibm_runtime
print(f"Qiskit IBM Runtime: {qiskit_ibm_runtime.__version__}")

import cirq
print(f"Cirq: {cirq.__version__}")

import pennylane
print(f"PennyLane: {pennylane.__version__}")

import numpy as np
print(f"NumPy: {np.__version__}")

import scipy
print(f"SciPy: {scipy.__version__}")

import networkx as nx
print(f"NetworkX: {nx.__version__}")

import matplotlib
print(f"Matplotlib: {matplotlib.__version__}")

# %% [markdown]
# ## Verify qc-compiler package

# %%
from qc_compiler import (
    CostModel,
    GateFusion,
    CircuitCutter,
    AdaptiveErrorMitigation,
    CoherenceAwareScheduler,
    CircuitBatcher,
    AutoTuner,
)

print(f"qc-compiler version: {__import__('qc_compiler').__version__}")
print("All imports successful!")

# %% [markdown]
# ## Verify Qiskit Aer simulator

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.measure_all()

simulator = AerSimulator()
result = simulator.run(qc, shots=1024).result()
counts = result.get_counts()
print(f"Bell state measurement: {counts}")
print("Aer simulator working!")

# %% [markdown]
# ## Verify IBM Quantum connectivity
#
# Uncomment and run the following cell after setting up your IBM Quantum account.

# %%
# from qiskit_ibm_runtime import QiskitRuntimeService
#
# # Save your credentials (run once):
# # QiskitRuntimeService.save_account(channel='ibm_quantum', token='YOUR_TOKEN')
#
# service = QiskitRuntimeService(channel='ibm_quantum')
# backends = service.backends()
# print(f'Available backends: {[b.name for b in backends]}')
# print('IBM Quantum connectivity verified!')
